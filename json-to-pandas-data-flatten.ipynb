# %%
# json url for flatten pandas dataframe
# Help url
"""
https://api.github.com/repos/pandas-dev/pandas/issues || 
https://stackoverflow.com/questions/52795561/flattening-nested-json-in-pandas-data-frame ||
https://towardsdatascience.com/flattening-json-objects-in-python-f5343c794b10 ||

"""
# Out:
# '\nhttps://api.github.com/repos/pandas-dev/pandas/issues \nhttps://stackoverflow.com/questions/52795561/flattening-nested-json-in-pandas-data-frame\n\n'

# %%
import requests

# %%
url_for = "https://api.github.com/repos/pandas-dev/pandas/issues"
r = requests.get(url_for)

# %%
r.status_code
# Out:
# 200

# %%
data = json.loads(r.content)

# %%
def flatten_json(nested_json, exclude=['']):
    """Flatten json object with nested keys into a single level.
        Args:
            nested_json: A nested json object.
            exclude: Keys to exclude from output.
        Returns:
            The flattened json object if successful, None otherwise.
    """
    out = {}

    def flatten(x, name='', exclude=exclude):
        if type(x) is dict:
            for a in x:
                if a not in exclude: flatten(x[a], name + a + '.')
        elif type(x) is list:
            i = 0
            for a in x:
                flatten(a, name + str(i) + '.')
                i += 1
        else:
            out[name[:-1]] = x

    flatten(nested_json)
    return out

# %%
df3 = pd.DataFrame([flatten_json(x) for x in data])

# %%
df3
# Out:
#                                                   url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                     repository_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas
# 1   https://api.github.com/repos/pandas-dev/pandas
# 2   https://api.github.com/repos/pandas-dev/pandas
# 3   https://api.github.com/repos/pandas-dev/pandas
# 4   https://api.github.com/repos/pandas-dev/pandas
# 5   https://api.github.com/repos/pandas-dev/pandas
# 6   https://api.github.com/repos/pandas-dev/pandas
# 7   https://api.github.com/repos/pandas-dev/pandas
# 8   https://api.github.com/repos/pandas-dev/pandas
# 9   https://api.github.com/repos/pandas-dev/pandas
# 10  https://api.github.com/repos/pandas-dev/pandas
# 11  https://api.github.com/repos/pandas-dev/pandas
# 12  https://api.github.com/repos/pandas-dev/pandas
# 13  https://api.github.com/repos/pandas-dev/pandas
# 14  https://api.github.com/repos/pandas-dev/pandas
# 15  https://api.github.com/repos/pandas-dev/pandas
# 16  https://api.github.com/repos/pandas-dev/pandas
# 17  https://api.github.com/repos/pandas-dev/pandas
# 18  https://api.github.com/repos/pandas-dev/pandas
# 19  https://api.github.com/repos/pandas-dev/pandas
# 20  https://api.github.com/repos/pandas-dev/pandas
# 21  https://api.github.com/repos/pandas-dev/pandas
# 22  https://api.github.com/repos/pandas-dev/pandas
# 23  https://api.github.com/repos/pandas-dev/pandas
# 24  https://api.github.com/repos/pandas-dev/pandas
# 25  https://api.github.com/repos/pandas-dev/pandas
# 26  https://api.github.com/repos/pandas-dev/pandas
# 27  https://api.github.com/repos/pandas-dev/pandas
# 28  https://api.github.com/repos/pandas-dev/pandas
# 29  https://api.github.com/repos/pandas-dev/pandas
#
#                                            labels_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                          comments_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                            events_url  \
# 0   https://api.github.com/repos/pandas-dev/pandas...
# 1   https://api.github.com/repos/pandas-dev/pandas...
# 2   https://api.github.com/repos/pandas-dev/pandas...
# 3   https://api.github.com/repos/pandas-dev/pandas...
# 4   https://api.github.com/repos/pandas-dev/pandas...
# 5   https://api.github.com/repos/pandas-dev/pandas...
# 6   https://api.github.com/repos/pandas-dev/pandas...
# 7   https://api.github.com/repos/pandas-dev/pandas...
# 8   https://api.github.com/repos/pandas-dev/pandas...
# 9   https://api.github.com/repos/pandas-dev/pandas...
# 10  https://api.github.com/repos/pandas-dev/pandas...
# 11  https://api.github.com/repos/pandas-dev/pandas...
# 12  https://api.github.com/repos/pandas-dev/pandas...
# 13  https://api.github.com/repos/pandas-dev/pandas...
# 14  https://api.github.com/repos/pandas-dev/pandas...
# 15  https://api.github.com/repos/pandas-dev/pandas...
# 16  https://api.github.com/repos/pandas-dev/pandas...
# 17  https://api.github.com/repos/pandas-dev/pandas...
# 18  https://api.github.com/repos/pandas-dev/pandas...
# 19  https://api.github.com/repos/pandas-dev/pandas...
# 20  https://api.github.com/repos/pandas-dev/pandas...
# 21  https://api.github.com/repos/pandas-dev/pandas...
# 22  https://api.github.com/repos/pandas-dev/pandas...
# 23  https://api.github.com/repos/pandas-dev/pandas...
# 24  https://api.github.com/repos/pandas-dev/pandas...
# 25  https://api.github.com/repos/pandas-dev/pandas...
# 26  https://api.github.com/repos/pandas-dev/pandas...
# 27  https://api.github.com/repos/pandas-dev/pandas...
# 28  https://api.github.com/repos/pandas-dev/pandas...
# 29  https://api.github.com/repos/pandas-dev/pandas...
#
#                                              html_url         id  \
# 0   https://github.com/pandas-dev/pandas/issues/36210  695507502
# 1     https://github.com/pandas-dev/pandas/pull/36209  695498559
# 2     https://github.com/pandas-dev/pandas/pull/36208  695486154
# 3     https://github.com/pandas-dev/pandas/pull/36207  695483220
# 4     https://github.com/pandas-dev/pandas/pull/36206  695463419
# 5     https://github.com/pandas-dev/pandas/pull/36205  695410876
# 6   https://github.com/pandas-dev/pandas/issues/36204  695410606
# 7     https://github.com/pandas-dev/pandas/pull/36201  695362610
# 8     https://github.com/pandas-dev/pandas/pull/36198  695354779
# 9   https://github.com/pandas-dev/pandas/issues/36197  695334022
# 10    https://github.com/pandas-dev/pandas/pull/36196  695305629
# 11  https://github.com/pandas-dev/pandas/issues/36195  695280288
# 12    https://github.com/pandas-dev/pandas/pull/36193  695222137
# 13  https://github.com/pandas-dev/pandas/issues/36189  695023951
# 14  https://github.com/pandas-dev/pandas/issues/36186  694961388
# 15    https://github.com/pandas-dev/pandas/pull/36185  694940719
# 16    https://github.com/pandas-dev/pandas/pull/36183  694894313
# 17    https://github.com/pandas-dev/pandas/pull/36182  694888000
# 18    https://github.com/pandas-dev/pandas/pull/36179  694633442
# 19    https://github.com/pandas-dev/pandas/pull/36178  694579458
# 20    https://github.com/pandas-dev/pandas/pull/36177  694578132
# 21    https://github.com/pandas-dev/pandas/pull/36175  694560851
# 22    https://github.com/pandas-dev/pandas/pull/36174  694534870
# 23    https://github.com/pandas-dev/pandas/pull/36172  694522333
# 24  https://github.com/pandas-dev/pandas/issues/36170  694490450
# 25    https://github.com/pandas-dev/pandas/pull/36169  694485212
# 26    https://github.com/pandas-dev/pandas/pull/36161  694369857
# 27    https://github.com/pandas-dev/pandas/pull/36159  694354285
# 28  https://github.com/pandas-dev/pandas/issues/36158  694260668
# 29    https://github.com/pandas-dev/pandas/pull/36157  694233814
#
#                              node_id  number  \
# 0           MDU6SXNzdWU2OTU1MDc1MDI=   36210
# 1   MDExOlB1bGxSZXF1ZXN0NDgxNzM0MTc5   36209
# 2   MDExOlB1bGxSZXF1ZXN0NDgxNzI0MDY5   36208
# 3   MDExOlB1bGxSZXF1ZXN0NDgxNzIxODA3   36207
# 4   MDExOlB1bGxSZXF1ZXN0NDgxNzA1MjUw   36206
# 5   MDExOlB1bGxSZXF1ZXN0NDgxNjU5MjU1   36205
# 6           MDU6SXNzdWU2OTU0MTA2MDY=   36204
# 7   MDExOlB1bGxSZXF1ZXN0NDgxNjE4MTg0   36201
# 8   MDExOlB1bGxSZXF1ZXN0NDgxNjExNTE2   36198
# 9           MDU6SXNzdWU2OTUzMzQwMjI=   36197
# 10  MDExOlB1bGxSZXF1ZXN0NDgxNTY5MTQx   36196
# 11          MDU6SXNzdWU2OTUyODAyODg=   36195
# 12  MDExOlB1bGxSZXF1ZXN0NDgxNDk1NTg0   36193
# 13          MDU6SXNzdWU2OTUwMjM5NTE=   36189
# 14          MDU6SXNzdWU2OTQ5NjEzODg=   36186
# 15  MDExOlB1bGxSZXF1ZXN0NDgxMjUwMTI0   36185
# 16  MDExOlB1bGxSZXF1ZXN0NDgxMjEwNjAz   36183
# 17  MDExOlB1bGxSZXF1ZXN0NDgxMjA1NDIw   36182
# 18  MDExOlB1bGxSZXF1ZXN0NDgwOTg0ODEy   36179
# 19  MDExOlB1bGxSZXF1ZXN0NDgwOTM4MDkz   36178
# 20  MDExOlB1bGxSZXF1ZXN0NDgwOTM3MDQ1   36177
# 21  MDExOlB1bGxSZXF1ZXN0NDgwOTIyMDQw   36175
# 22  MDExOlB1bGxSZXF1ZXN0NDgwODk5MzUw   36174
# 23  MDExOlB1bGxSZXF1ZXN0NDgwODg4NTE2   36172
# 24          MDU6SXNzdWU2OTQ0OTA0NTA=   36170
# 25  MDExOlB1bGxSZXF1ZXN0NDgwODU2MDA4   36169
# 26  MDExOlB1bGxSZXF1ZXN0NDgwNzU2MDg4   36161
# 27  MDExOlB1bGxSZXF1ZXN0NDgwNzQyNDEy   36159
# 28          MDU6SXNzdWU2OTQyNjA2Njg=   36158
# 29  MDExOlB1bGxSZXF1ZXN0NDgwNjM4NzM0   36157
#
#                                                 title  ...  \
# 0   API/DEPR: casting bool-indexer to slice in dt6...  ...
# 1                          REF: share more EA methods  ...
# 2             BUG: GroupbyRolling with an empty frame  ...
# 3         Fixed pandas.json_normalize doctests errors  ...
# 4   REF: implement Categorical._box_func, make _bo...  ...
# 5                                        DOC: doc fix  ...
# 6        BUG: Incorrect parsing of ISO 8601 durations  ...
# 7   BUG: Don't raise for NDFrame.mask with nullabl...  ...
# 8   [BUG]: Groupy and Resample miscalculated aggre...  ...
# 9   BUG: DataFrameGroupBy.rolling on an empty Data...  ...
# 10  CLN: remove unused return value in _create_blocks  ...
# 11  Proposal for future copy / view semantics in i...  ...
# 12  CLN: remove unnecessary trailing commas on iss...  ...
# 13  BUG: Inconsistent behavior of index values for...  ...
# 14                                         RLS: 1.1.3  ...
# 15                                       BUG: GH36113  ...
# 16                                   DOC: Start 1.1.3  ...
# 17                        DOC: release date for 1.1.2  ...
# 18    DEPR: string indexing along index for datetimes  ...
# 19    STY: de-privatize names imported across modules  ...
# 20                         Move sort index to generic  ...
# 21  BUG: read_excel for ods files raising UnboundL...  ...
# 22  BUG: Ensure read_spss accepts pathlib Paths (G...  ...
# 23             Clarify docs for df.to_sql `chunksize`  ...
# 24  DOC: index described as a "set" but permits du...  ...
# 25  BUG GH31355 fixed by adding more relevant erro...  ...
# 26  BUG: Enable Series.equals to compare iterables...  ...
# 27  ENH: add set_data_classes method for CSS class...  ...
# 28  BUG: indices raise exception with GroupBy init...  ...
# 29  DOC: Fix capitalization among headings in doc/...  ...
#
#                             assignees_0_following_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   https://api.github.com/users/mroeschke/followi...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                                 assignees_0_gists_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   https://api.github.com/users/mroeschke/gists{/...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                               assignees_0_starred_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   https://api.github.com/users/mroeschke/starred...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                         assignees_0_subscriptions_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   https://api.github.com/users/mroeschke/subscri...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                   assignees_0_organizations_url  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                           NaN
# 7                                           NaN
# 8                                           NaN
# 9   https://api.github.com/users/mroeschke/orgs
# 10                                          NaN
# 11                                          NaN
# 12                                          NaN
# 13                                          NaN
# 14                                          NaN
# 15                                          NaN
# 16                                          NaN
# 17                                          NaN
# 18                                          NaN
# 19                                          NaN
# 20                                          NaN
# 21                                          NaN
# 22                                          NaN
# 23                                          NaN
# 24                                          NaN
# 25                                          NaN
# 26                                          NaN
# 27                                          NaN
# 28                                          NaN
# 29                                          NaN
#
#                            assignees_0_repos_url  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# 5                                            NaN
# 6                                            NaN
# 7                                            NaN
# 8                                            NaN
# 9   https://api.github.com/users/mroeschke/repos
# 10                                           NaN
# 11                                           NaN
# 12                                           NaN
# 13                                           NaN
# 14                                           NaN
# 15                                           NaN
# 16                                           NaN
# 17                                           NaN
# 18                                           NaN
# 19                                           NaN
# 20                                           NaN
# 21                                           NaN
# 22                                           NaN
# 23                                           NaN
# 24                                           NaN
# 25                                           NaN
# 26                                           NaN
# 27                                           NaN
# 28                                           NaN
# 29                                           NaN
#
#                                assignees_0_events_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   https://api.github.com/users/mroeschke/events{...
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                       assignees_0_received_events_url assignees_0_type  \
# 0                                                 NaN              NaN
# 1                                                 NaN              NaN
# 2                                                 NaN              NaN
# 3                                                 NaN              NaN
# 4                                                 NaN              NaN
# 5                                                 NaN              NaN
# 6                                                 NaN              NaN
# 7                                                 NaN              NaN
# 8                                                 NaN              NaN
# 9   https://api.github.com/users/mroeschke/receive...             User
# 10                                                NaN              NaN
# 11                                                NaN              NaN
# 12                                                NaN              NaN
# 13                                                NaN              NaN
# 14                                                NaN              NaN
# 15                                                NaN              NaN
# 16                                                NaN              NaN
# 17                                                NaN              NaN
# 18                                                NaN              NaN
# 19                                                NaN              NaN
# 20                                                NaN              NaN
# 21                                                NaN              NaN
# 22                                                NaN              NaN
# 23                                                NaN              NaN
# 24                                                NaN              NaN
# 25                                                NaN              NaN
# 26                                                NaN              NaN
# 27                                                NaN              NaN
# 28                                                NaN              NaN
# 29                                                NaN              NaN
#
#    assignees_0_site_admin
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     NaN
# 4                     NaN
# 5                     NaN
# 6                     NaN
# 7                     NaN
# 8                     NaN
# 9                   False
# 10                    NaN
# 11                    NaN
# 12                    NaN
# 13                    NaN
# 14                    NaN
# 15                    NaN
# 16                    NaN
# 17                    NaN
# 18                    NaN
# 19                    NaN
# 20                    NaN
# 21                    NaN
# 22                    NaN
# 23                    NaN
# 24                    NaN
# 25                    NaN
# 26                    NaN
# 27                    NaN
# 28                    NaN
# 29                    NaN
#
# [30 rows x 134 columns]

# %%
df3.to_csv('flatten.csv')

# %%
# from pandas.io.json import json_normalize
# import pandas as pd
# df = json_normalize(data, record_path=['labels'])
# df2 = pd.DataFrame(data)

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
# df2[user.id] = df['user']['node_id']
# 'aa'

# %%
df2['user'][0]['node_id']
# Out:
# 'MDQ6VXNlcjgwNzg5Njg='

# %%
df.iloc[:,7:]
'aa'
# Out:
# 'aa'

# %%
df.iloc[:,7:].shape
# Out:
# (30, 90)

# %%
# columns stat with somethings
filter_col = [col for col in df if col.startswith('labels')]
df[filter_col]
'aa'
# Out:
# 'aa'
